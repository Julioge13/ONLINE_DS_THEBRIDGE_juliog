# %%
import pandas as pd
import glob
import re

# %%
ruta_archivo = r'C:\Users\julio\Desktop\The_Bridge\Temario\EDA\Dataset\Banco_de_Espanya\PIB_ramas_actividad\be23cclean.xlsx'

# Cargar el archivo en un DataFrame saltando las primeras 5 filas
df = pd.read_excel(ruta_archivo)

df
# Out:
#     DESCRIPCIÓN DE LA SERIE  \
# 0                  MAR 1995
# 1                  JUN 1995
# 2                  SEP 1995
# 3                  DIC 1995
# 4                  MAR 1996
# ..                      ...
# 107                DIC 2021
# 108                MAR 2022
# 109                JUN 2022
# 110                SEP 2022
# 111                DIC 2022
#
#      CNE. Base 2016. VAB. Agricultura, ganadería, silv. y pesca. Precios corrientes (millones euros)  \
# 0                                                 3644
# 1                                                 5104
# 2                                                 3771
# 3                                                 5373
# 4                                                 4553
# ..                                                 ...
# 107                                              11667
# 108                                               6331
# 109                                               7115
# ...
